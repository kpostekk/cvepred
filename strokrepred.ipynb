# %%
from strokepred.comapre_models import model_comparison
from IPython.display import display

# %%
display(model_comparison)
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# et                 Extra Trees Classifier    0.9685  0.9916  0.9550  0.9815
# rf               Random Forest Classifier    0.9683  0.9949  0.9575  0.9786
# catboost              CatBoost Classifier    0.9678  0.9928  0.9512  0.9840
# lr                    Logistic Regression    0.9638  0.9891  0.9340  0.9933
# gbc          Gradient Boosting Classifier    0.9613  0.9905  0.9398  0.9820
# ada                  Ada Boost Classifier    0.9514  0.9881  0.9394  0.9628
# ridge                    Ridge Classifier    0.9445  0.9886  0.8894  0.9995
# lda          Linear Discriminant Analysis    0.9443  0.9886  0.8889  0.9995
# dt               Decision Tree Classifier    0.9323  0.9323  0.9441  0.9228
# knn                K Neighbors Classifier    0.8838  0.9498  0.9794  0.8223
# svm                   SVM - Linear Kernel    0.8564  0.9706  0.8670  0.8737
# nb                            Naive Bayes    0.7072  0.9247  0.9844  0.6333
# qda       Quadratic Discriminant Analysis    0.5018  0.9637  1.0000  0.5007
#
#               F1   Kappa     MCC  TT (Sec)
# et        0.9680  0.9369  0.9374     0.021
# rf        0.9679  0.9365  0.9368     0.029
# catboost  0.9672  0.9357  0.9363     0.487
# lr        0.9627  0.9277  0.9295     0.068
# gbc       0.9604  0.9226  0.9236     0.047
# ada       0.9509  0.9029  0.9033     0.015
# ridge     0.9412  0.8890  0.8945     0.002
# lda       0.9409  0.8886  0.8942     0.002
# dt        0.9331  0.8646  0.8652     0.003
# knn       0.8939  0.7675  0.7823     0.005
# svm       0.8553  0.7128  0.7364     0.005
# nb        0.7707  0.4145  0.4982     0.002
# qda       0.6673  0.0042  0.0320     0.003

# %% [markdown]
# Patrząc na powyższą tabelę możemy wyróżnić następujące modele:
#
# 1. **Extra Trees Classifier** - jest to model z najwyższym wynikiem "Accuracy" oraz "F1". Również należy do modeli z krótkim czasem uczenia.
# 2. **CatBoost Classifier** - mimo, że nie jest to model z najwyższym wynikiem "Accuracy", jednakże balansuje wszystkie miary, co daje mu wysoką pozycję w rankingu. Jest to model, który będzie bardziej "ostrożny" w klasyfikacji.
# 3. **Random Forest Classifier** - osiąga 2 najwyższy wynik "Accuracy" jednakże, rozstrzał w innych miarach jest większy niż w przypadku modelu "Extra Trees Classifier" czy "CatBoost".
#
# Powyższa tabela pokrywa się z wnykami [dotychczasowych badań dotyczących przewidywania udarów](https://pubmed.ncbi.nlm.nih.gov/39355095/).

# %%
from pycaret.classification import predict_model
from strokepred.comapre_models import best_model
from strokepred.dataset import preprocess_dataset
import pandas as pd

sample_data = preprocess_dataset().sample(5)

results = predict_model(best_model, data=sample_data)

results = results.rename(columns={"stroke": "dataset stroke", "prediction_label": "predicted stroke"})
results = results.drop(columns=["prediction_score"])
results["predicted stroke"] = results["predicted stroke"].apply(bool)

display(results)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5fed4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5fed4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5fed4_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_5fed4_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_5fed4_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_5fed4_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_5fed4_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_5fed4_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_5fed4_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5fed4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5fed4_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_5fed4_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_5fed4_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_5fed4_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_5fed4_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_5fed4_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_5fed4_row0_col6" class="data row0 col6" >1.0000</td>
#       <td id="T_5fed4_row0_col7" class="data row0 col7" >1.0000</td>
#     </tr>
#   </tbody>
# </table>
#             age  hypertension  heart_disease  ever_married  avg_glucose_level  \
# 6121  78.688194         False           True          True         106.080696
# 1003  79.000000         False          False          True         113.410004
# 1259  67.000000         False          False          True          81.680000
# 888   71.000000         False          False          True         134.649994
# 475   62.000000         False          False          True         136.179993
#
#             bmi  gender_Female  gender_Male  work_type_Govt_job  \
# 6121  31.057014           True         True               False
# 1003  35.000000          False         True               False
# 1259  30.400000           True        False               False
# 888   32.400002           True        False               False
# 475   32.200001          False         True               False
#
#       work_type_Never_worked  ...  work_type_Self-employed  \
# 6121                   False  ...                     True
# 1003                   False  ...                     True
# 1259                   False  ...                    False
# 888                    False  ...                    False
# 475                    False  ...                     True
#
#       work_type_children  Residence_type_Rural  Residence_type_Urban  \
# 6121               False                  True                  True
# 1003               False                 False                  True
# 1259               False                  True                 False
# 888                False                 False                  True
# 475                False                  True                 False
#
#       smoking_status_Unknown  smoking_status_formerly smoked  \
# 6121                   False                            True
# 1003                   False                           False
# 1259                   False                           False
# 888                     True                           False
# 475                     True                           False
#
#       smoking_status_never smoked  smoking_status_smokes  dataset stroke  \
# 6121                         True                  False            True
# 1003                         True                  False           False
# 1259                         True                  False           False
# 888                         False                  False           False
# 475                         False                  False           False
#
#       predicted stroke
# 6121              True
# 1003             False
# 1259             False
# 888              False
# 475              False
#
# [5 rows x 21 columns]
