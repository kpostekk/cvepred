# %%
from strokepred.dataset import create_dataset
from strokepred.comapre_models import model_comparison
from IPython.display import display

# %%
display(create_dataset())
# Out:
#       gender   age  hypertension  ...   bmi   smoking_status stroke
# 0       Male  67.0         False  ...  36.6  formerly smoked   True
# 1     Female  61.0         False  ...  28.1     never smoked   True
# 2       Male  80.0         False  ...  32.5     never smoked   True
# 3     Female  49.0         False  ...  34.4           smokes   True
# 4     Female  79.0          True  ...  24.0     never smoked   True
# ...      ...   ...           ...  ...   ...              ...    ...
# 5105  Female  80.0          True  ...  28.1     never smoked  False
# 5106  Female  81.0         False  ...  40.0     never smoked  False
# 5107  Female  35.0         False  ...  30.6     never smoked  False
# 5108    Male  51.0         False  ...  25.6  formerly smoked  False
# 5109  Female  44.0         False  ...  26.2          Unknown  False
#
# [5104 rows x 11 columns]

# %%
display(model_comparison)
# Out:
#                                     Model  Accuracy  ...     MCC  TT (Sec)
# et                 Extra Trees Classifier    0.9685  ...  0.9374     0.026
# rf               Random Forest Classifier    0.9683  ...  0.9368     0.035
# catboost              CatBoost Classifier    0.9678  ...  0.9363     0.526
# lr                    Logistic Regression    0.9638  ...  0.9295     0.015
# gbc          Gradient Boosting Classifier    0.9613  ...  0.9236     0.046
# ada                  Ada Boost Classifier    0.9514  ...  0.9033     0.017
# ridge                    Ridge Classifier    0.9445  ...  0.8945     0.002
# lda          Linear Discriminant Analysis    0.9443  ...  0.8942     0.003
# dt               Decision Tree Classifier    0.9323  ...  0.8652     0.004
# knn                K Neighbors Classifier    0.8838  ...  0.7823     0.007
# svm                   SVM - Linear Kernel    0.8564  ...  0.7364     0.005
# nb                            Naive Bayes    0.7072  ...  0.4982     0.002
# qda       Quadratic Discriminant Analysis    0.5018  ...  0.0320     0.003
#
# [13 rows x 9 columns]

# %% [markdown]
# Patrząc na powyższą tabelę możemy wyróżnić następujące modele:
#
# 1. **Extra Trees Classifier** - jest to model z najwyższym wynikiem "Accuracy" oraz "F1". Również należy do modeli z krótkim czasem uczenia.
# 2. **CatBoost Classifier** - mimo, że nie jest to model z najwyższym wynikiem "Accuracy", jednakże balansuje wszystkie miary, co daje mu wysoką pozycję w rankingu. Jest to model, który będzie bardziej "ostrożny" w klasyfikacji.
# 3. **Random Forest Classifier** - osiąga 2 najwyższy wynik "Accuracy" jednakże, rozstrzał w innych miarach jest większy niż w przypadku modelu "Extra Trees Classifier" czy "CatBoost".
#
# Powyższa tabela pokrywa się z wnykami [dotychczasowych badań dotyczących przewidywania udarów](https://pubmed.ncbi.nlm.nih.gov/39355095/).

# %%
from pycaret.classification import predict_model
from strokepred.model import strokepred_model
from strokepred.dataset import balanced_dataset

sample_data = balanced_dataset().sample(5)

results = predict_model(strokepred_model, data=sample_data, verbose=False)

results = results.rename(columns={"stroke": "dataset stroke", "prediction_label": "predicted stroke"})
results = results.drop(columns=["prediction_score"])
results["predicted stroke"] = results["predicted stroke"].apply(bool)

display(results)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 2
#       1 from pycaret.classification import predict_model
# ----> 2 from strokepred.model import strokepred_model
#       3 from strokepred.dataset import balanced_dataset
#       5 sample_data = balanced_dataset().sample(5)
#
# ImportError: cannot import name 'strokepred_model' from 'strokepred.model' (/home/kpostek/Documents/24477_StorkePred/strokepred/model.py)
