# %%
from cvepred.dataset import create_dataset, balanced_dataset
import pandas as pd
import ydata_profiling as ydp

df = create_dataset()
display(df)

# # Print the profiling report
# profile = ydp.ProfileReport(df)
# profile.to_notebook_iframe()

df_encoded = pd.get_dummies(df, dtype=int)
display(df_encoded)
df_balanced = balanced_dataset(df_encoded)
# df_decoded = pd.from_dummies(df_balanced)
display(df_balanced)
# Out:
#                    attackVector attackComplexity privilegesRequired  \
# cve_id
# CVE-2010-0012           NETWORK              LOW               NONE
# CVE-2010-0013           NETWORK              LOW               NONE
# CVE-2010-0050           NETWORK              LOW               NONE
# CVE-2010-0109  ADJACENT_NETWORK              LOW               NONE
# CVE-2010-0127           NETWORK              LOW               NONE
# ...                         ...              ...                ...
# CVE-2024-9988           NETWORK              LOW               NONE
# CVE-2024-9989           NETWORK              LOW               NONE
# CVE-2024-9990           NETWORK              LOW               NONE
# CVE-2024-9996             LOCAL              LOW               NONE
# CVE-2024-9997             LOCAL              LOW               NONE
#
#               userInteraction      scope confidentialityImpact  \
# cve_id
# CVE-2010-0012        REQUIRED  UNCHANGED                  HIGH
# ...
